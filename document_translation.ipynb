# %%
# !pip install requests beautifulsoup4 openai langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 1.9 MB/s eta 0:00:00
# ...

# %%
import requests
from bs4 import BeautifulSoup

def extract_text_from_url(url):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        # Remove script and style elements
        for script_or_style in soup(['script', 'style']):
            script_or_style.decompose()

        texto = soup.get_text(separator='  ')
        # Clean up text
        linhas = (line.strip() for line in texto.splitlines())
        parts = (phrase.strip() for line in linhas for phrase in line.split("  "))
        texto_limpo = '\n'.join(part for part in parts if part)
        return texto_limpo

    else:
        print(f"Failed to fetch the URL. Status code: {response.status_code}")
        return None

extract_text_from_url('https://dev.to/umesh_malik/openai-gpt-53-instant-fewer-refusals-better-web-answers-and-a-smoother-chatgpt-147o')
# Out:
# 'OpenAI GPT-5.3 Instant: Fewer Refusals, Better Web Answers, and a Smoother ChatGPT - DEV Community\nSkip to content\nNavigation menu\nSearch\nPowered by Algolia\nSearch\nLog in\nCreate account\nDEV Community\nClose\nAdd reaction\nLike\nUnicorn\nExploding Head\nRaised Hands\nFire\nJump to Comments\nSave\nBoost\nMore...\nCopy link\nCopy link\nCopied to Clipboard\nShare to X\nShare to LinkedIn\nShare to Facebook\nShare to Mastodon\nReport Abuse\nUmesh Malik\nPosted on\nMar 3\n• Edited on\nMar 6\n• Originally published at\numesh-malik.com\nOpenAI GPT-5.3 Instant: Fewer Refusals, Better Web Answers, and a Smoother ChatGPT\n#\nai\n#\ngpt5\n#\nopenai\n#\nchatgpt\nOpenAI just shipped the most user-visible model update of 2026 — and it is not about benchmarks or parameter counts.\nGPT-5.3 Instant\nis about fixing the things that make ChatGPT frustrating to use every day: unnecessary refusals, preachy disclaimers, stale web answers, and a tone that sometimes felt like talking to a compliance 
# ...

# %%
from langchain_openai.chat_models.azure import AzureChatOpenAI

client = AzureChatOpenAI(
    azure_endpoint="https://oai-dio-bootcamp-eastus-pl-001.openai.azure.com/",
    api_key="5Jsi3MJnIfgLHZ6tygceZfnC9bHnRsK8cO6BCrzn1sdghUtgFLiUJQQJ99CCACYeBjFXJ3w3AAABACOGgQoB",
    api_version="2024-07-01-preview", # Corrected API version
    deployment_name="gpt-4o-mini",
    max_retries=0
)

def translate_article(text, lang):
    messages = [
        ("system", "Você atua como tradutor de textos."),
        ("user", f"Traduza o seguinte texto para o idioma {lang} e responda apenas com a tradução em markdown:\n\n{text}")
    ]

    response = client.invoke(messages)
    print(response.content)
    return response.content

# Example usage with a snippet of text
translate_article("OpenAI just shipped the most user-visible model update of 2026 — and it is not about benchmarks or parameter counts", "português")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /tmp/ipykernel_686/4083768593.py in <cell line: 0>()
#      20
#      21 # Example usage with a snippet of text
# ---> 22 translate_article("OpenAI just shipped the most user-visible model update of 2026 — and it is not about benchmarks or parameter counts", "português")
#
# /tmp/ipykernel_686/4083768593.py in translate_article(text, lang)
#      15     ]
#      16
# ---> 17     response = client.invoke(messages)
#      18     print(response.content)
#      19     return response.content
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     400             cast(
#     401                 "ChatGeneration",
# --> 402                 self.generate_prompt(
#     403                     [self._convert_input(input)],
# ...

# %%
url = 'https://dev.to/umesh_malik/openai-gpt-53-instant-fewer-refusals-better-web-answers-and-a-smoother-chatgpt-147o'
text = extract_text_from_url(url)
article = translate_article((text,"pt-br")

print(article)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /tmp/ipykernel_686/2645121086.py in <cell line: 0>()
#       1 url = 'https://dev.to/umesh_malik/openai-gpt-53-instant-fewer-refusals-better-web-answers-and-a-smoother-chatgpt-147o'
#       2 text = extract_text_from_url(url)
# ----> 3 article = translate_article(text,"pt-br")
#       4
#       5 print(article)
#
# /tmp/ipykernel_686/2636521476.py in translate_article(text, lang)
#      15     ]
#      16
# ---> 17     response = client.invoke(messages)
#      18     print(response.content)
#      19     return response.content
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     400             cast(
#     401                 "ChatGeneration",
# --> 402                 self.generate_prompt(
# ...
